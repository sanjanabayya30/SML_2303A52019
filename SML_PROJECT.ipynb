# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanabayya30/SML_2303A52019/blob/main/SML_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('/content/drive/MyDrive/archive.zip',usecols=(['Heart_Rate_Variability','Body_Temperature']))
data.head()
#print(data)
data.shape
#data.info()
data.describe()
data.skew()
data.kurt()
# Out:
# Heart_Rate_Variability    0.072562
# Body_Temperature          0.058403
# dtype: float64

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
plt.plot(data, color='r')
plt.show()

# %%
x=data.drop('Body_Temperature',axis=1)
y=data.Body_Temperature
print(x)
print(y)
from sklearn import linear_model
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
#      Heart_Rate_Variability
# 0                 79.934283
# 1                 67.234714
# 2                 82.953771
# 3                100.460597
# 4                 65.316933
# ..                      ...
# 995               64.377994
# 996              105.953731
# 997               82.816857
# 998               58.576420
# 999               81.451656
#
# [1000 rows x 1 columns]
# 0      37.199678
# 1      36.962317
# 2      36.529815
# 3      36.176532
# 4      36.849112
#          ...
# 995    37.035075
# 996    36.486739
# 997    36.059063
# 998    36.418467
# 999    36.127549
# Name: Body_Temperature, Length: 1000, dtype: float64
# (800, 1)
# (200, 1)
# (800,)
# (200,)

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(x_train,y_train)
reg.intercept_
reg.coef_
# Out:
# array([-0.00072272])

# %%
y_pred=reg.predict(x_test)
y_pred
# Out:
# array([36.54824771, 36.52924134, 36.52664055, 36.5347125 , 36.54334337,
#        36.54823423, 36.53295951, 36.53526123, 36.51992209, 36.55689789,
#        36.55338282, 36.53268843, 36.53029856, 36.52606857, 36.55976214,
#        36.52492889, 36.55804596, 36.52643355, 36.56332272, 36.542712  ,
#        36.51161638, 36.55220181, 36.54153647, 36.52250782, 36.52329726,
#        36.53940422, 36.54879495, 36.54998648, 36.54671053, 36.54038855,
#        36.54363464, 36.53533988, 36.50303806, 36.53218013, 36.53665121,
#        36.53468925, 36.5317879 , 36.53515088, 36.54484296, 36.5590619 ,
#        36.54894705, 36.51240547, 36.56231003, 36.52503373, 36.52512284,
#        36.52956434, 36.5229891 , 36.51949601, 36.52853277, 36.55067403,
#        36.55135932, 36.54840563, 36.58524069, 36.54228414, 36.5160217 ,
#        36.52924351, 36.52157714, 36.51755723, 36.52570824, 36.54027116,
#        36.54347094, 36.56011709, 36.56162527, 36.52273512, 36.51992192,
# ...

# %%
y_test
# Out:
# 993    36.854152
# 859    36.630161
# 298    36.633696
# 553    36.086560
# 672    36.304121
#          ...
# 679    36.284190
# 722    36.869405
# 215    37.123871
# 653    36.323417
# 150    36.004304
# Name: Body_Temperature, Length: 200, dtype: float64

# %%
from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,y_pred))
# Out:
# Mean Absolute Error: 0.41407450512834215
# Mean Squared Error: 0.2739580742150403
